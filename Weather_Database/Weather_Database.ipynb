# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
from scipy.stats import linregress
from citipy import citipy

# %%
# 3 Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# 4 Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# to make the full url for the city requested
url_base = "http://api.openweathermap.org/data/2.5/weather?units=Imperial"
# City = "Nashville"
url = url_base + "&APPID=" + weather_api_key

# %%
# 5 to make the full url for the city requested
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. Replace spaces in the city name with a + so that it is a complete city name.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]['lat']
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_current = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_current,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kemijarvi
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | cernay
# Processing Record 4 of Set 1 | poum
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | altay
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | jezerski
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | jatiroto
# Processing Record 13 of Set 1 | ambilobe
# Processing Record 14 of Set 1 | coquimbo
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | jumla
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | pushkinskiye gory
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | mehamn
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | aklavik
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | biak
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | praia
# Processing Record 36 of Set 1 | bongandanga
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | bac lieu
# Processing Record 41 of Set 1 | balakhta
# Processing Record 42 of Set 1 | pousat
# City not found. Skipping...
# Processing Record 43 of Set 1 | lucapa
# Processing Record 44 of Set 1 | along
# Processing Record 45 of Set 1 | lagoa
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | luoyang
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | los llanos de aridane
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | macau
# Processing Record 4 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 2 | egvekinot
# Processing Record 6 of Set 2 | forbes
# Processing Record 7 of Set 2 | imbituba
# Processing Record 8 of Set 2 | woodward
# Processing Record 9 of Set 2 | ilhabela
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | walvis bay
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | shimoda
# Processing Record 15 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 2 | callaway
# Processing Record 17 of Set 2 | maarianhamina
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | sao filipe
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | araouane
# Processing Record 25 of Set 2 | hami
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | nouadhibou
# Processing Record 28 of Set 2 | shingu
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | lavrentiya
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | juquia
# Processing Record 33 of Set 2 | xudat
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | escanaba
# Processing Record 37 of Set 2 | csengod
# Processing Record 38 of Set 2 | arman
# Processing Record 39 of Set 2 | paamiut
# Processing Record 40 of Set 2 | namibe
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | tuatapere
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | samana
# Processing Record 47 of Set 2 | dingle
# Processing Record 48 of Set 2 | jiuquan
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | praya
# Processing Record 2 of Set 3 | kahului
# Processing Record 3 of Set 3 | vallenar
# Processing Record 4 of Set 3 | tocopilla
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | boden
# Processing Record 7 of Set 3 | terrace bay
# Processing Record 8 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 3 | bilibino
# Processing Record 10 of Set 3 | ilulissat
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 3 | vestmannaeyjar
# Processing Record 17 of Set 3 | asau
# Processing Record 18 of Set 3 | upata
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | krasnoselkup
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | nyanza
# Processing Record 26 of Set 3 | banda aceh
# Processing Record 27 of Set 3 | sept-iles
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | athabasca
# Processing Record 30 of Set 3 | dawlatabad
# Processing Record 31 of Set 3 | mandalgovi
# Processing Record 32 of Set 3 | evensk
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | omsukchan
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | fortuna foothills
# Processing Record 40 of Set 3 | isparta
# Processing Record 41 of Set 3 | orebro
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | quatre cocos
# Processing Record 44 of Set 3 | mount isa
# Processing Record 45 of Set 3 | sovetskaya
# Processing Record 46 of Set 3 | bathsheba
# Processing Record 47 of Set 3 | coahuayana
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | morondava
# Processing Record 3 of Set 4 | te anau
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 4 | san ramon
# Processing Record 7 of Set 4 | singaparna
# Processing Record 8 of Set 4 | estevan
# Processing Record 9 of Set 4 | bella union
# Processing Record 10 of Set 4 | najran
# Processing Record 11 of Set 4 | brae
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | waipawa
# Processing Record 14 of Set 4 | wageningen
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | sosnovo-ozerskoye
# Processing Record 17 of Set 4 | kysyl-syr
# Processing Record 18 of Set 4 | gat
# Processing Record 19 of Set 4 | maloyaz
# City not found. Skipping...
# Processing Record 20 of Set 4 | strezhevoy
# Processing Record 21 of Set 4 | srednekolymsk
# Processing Record 22 of Set 4 | bonthe
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | aktash
# Processing Record 25 of Set 4 | vao
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | preili
# Processing Record 28 of Set 4 | muros
# Processing Record 29 of Set 4 | tabuk
# Processing Record 30 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 4 | labuhan
# Processing Record 32 of Set 4 | ginir
# Processing Record 33 of Set 4 | teguldet
# Processing Record 34 of Set 4 | ugoofaaru
# Processing Record 35 of Set 4 | san andres
# Processing Record 36 of Set 4 | bilma
# Processing Record 37 of Set 4 | makinsk
# Processing Record 38 of Set 4 | ambovombe
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | mahenge
# Processing Record 41 of Set 4 | tuy hoa
# Processing Record 42 of Set 4 | deputatskiy
# Processing Record 43 of Set 4 | botshabelo
# Processing Record 44 of Set 4 | marsabit
# Processing Record 45 of Set 4 | severomorsk
# Processing Record 46 of Set 4 | cape town
# Processing Record 47 of Set 4 | bosaso
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | baruun-urt
# Processing Record 50 of Set 4 | clarence town
# Processing Record 1 of Set 5 | blackwater
# Processing Record 2 of Set 5 | nemencine
# Processing Record 3 of Set 5 | kloulklubed
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | sorong
# Processing Record 6 of Set 5 | olafsvik
# Processing Record 7 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 5 | ambon
# Processing Record 9 of Set 5 | tabou
# Processing Record 10 of Set 5 | totness
# Processing Record 11 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | terney
# Processing Record 14 of Set 5 | forio
# Processing Record 15 of Set 5 | puerto escondido
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | ternate
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | oxbow
# Processing Record 20 of Set 5 | carman
# Processing Record 21 of Set 5 | kavieng
# Processing Record 22 of Set 5 | henties bay
# Processing Record 23 of Set 5 | oriximina
# Processing Record 24 of Set 5 | manzhouli
# Processing Record 25 of Set 5 | ngunguru
# Processing Record 26 of Set 5 | zhangye
# Processing Record 27 of Set 5 | olinda
# Processing Record 28 of Set 5 | georgetown
# Processing Record 29 of Set 5 | cabo san lucas
# Processing Record 30 of Set 5 | chifeng
# Processing Record 31 of Set 5 | bereda
# Processing Record 32 of Set 5 | linjiang
# Processing Record 33 of Set 5 | hirara
# Processing Record 34 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 5 | vung tau
# Processing Record 36 of Set 5 | thessalon
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | hokitika
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | gerash
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | zhigansk
# Processing Record 45 of Set 5 | malaya purga
# Processing Record 46 of Set 5 | west plains
# Processing Record 47 of Set 5 | coari
# Processing Record 48 of Set 5 | yenagoa
# Processing Record 49 of Set 5 | poli
# Processing Record 50 of Set 5 | iqaluit
# Processing Record 1 of Set 6 | murray bridge
# Processing Record 2 of Set 6 | alakurtti
# Processing Record 3 of Set 6 | bumba
# Processing Record 4 of Set 6 | beloha
# Processing Record 5 of Set 6 | knysna
# Processing Record 6 of Set 6 | samarai
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | nakonde
# Processing Record 9 of Set 6 | port lincoln
# Processing Record 10 of Set 6 | yulara
# Processing Record 11 of Set 6 | pontianak
# Processing Record 12 of Set 6 | kafanchan
# Processing Record 13 of Set 6 | riberalta
# Processing Record 14 of Set 6 | san juan
# Processing Record 15 of Set 6 | noumea
# Processing Record 16 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 6 | banepa
# Processing Record 18 of Set 6 | hamilton
# Processing Record 19 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 6 | strathmore
# Processing Record 21 of Set 6 | gorontalo
# Processing Record 22 of Set 6 | hulan ergi
# Processing Record 23 of Set 6 | mercedes
# Processing Record 24 of Set 6 | aksu
# Processing Record 25 of Set 6 | molteno
# Processing Record 26 of Set 6 | zhob
# Processing Record 27 of Set 6 | mengcheng
# Processing Record 28 of Set 6 | bonavista
# Processing Record 29 of Set 6 | sioux lookout
# Processing Record 30 of Set 6 | vaitape
# Processing Record 31 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 32 of Set 6 | half moon bay
# Processing Record 33 of Set 6 | esso
# Processing Record 34 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 35 of Set 6 | porto novo
# Processing Record 36 of Set 6 | lac du bonnet
# Processing Record 37 of Set 6 | coihaique
# Processing Record 38 of Set 6 | beringovskiy
# Processing Record 39 of Set 6 | hasaki
# Processing Record 40 of Set 6 | geraldton
# Processing Record 41 of Set 6 | gigmoto
# Processing Record 42 of Set 6 | east london
# Processing Record 43 of Set 6 | papetoai
# Processing Record 44 of Set 6 | ahipara
# Processing Record 45 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 48 of Set 6 | manadhoo
# Processing Record 49 of Set 6 | urucara
# Processing Record 50 of Set 6 | ligayan
# Processing Record 1 of Set 7 | salinopolis
# Processing Record 2 of Set 7 | nishihara
# Processing Record 3 of Set 7 | lengshuijiang
# Processing Record 4 of Set 7 | tautira
# Processing Record 5 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 6 of Set 7 | biskamzha
# Processing Record 7 of Set 7 | chapais
# Processing Record 8 of Set 7 | beisfjord
# Processing Record 9 of Set 7 | mount gambier
# Processing Record 10 of Set 7 | killybegs
# Processing Record 11 of Set 7 | broome
# Processing Record 12 of Set 7 | jacareacanga
# Processing Record 13 of Set 7 | narsaq
# Processing Record 14 of Set 7 | carauari
# Processing Record 15 of Set 7 | atambua
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | urdoma
# Processing Record 18 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 19 of Set 7 | pankrushikha
# Processing Record 20 of Set 7 | viedma
# Processing Record 21 of Set 7 | ambanja
# Processing Record 22 of Set 7 | price
# Processing Record 23 of Set 7 | colac
# Processing Record 24 of Set 7 | vostok
# Processing Record 25 of Set 7 | manggar
# Processing Record 26 of Set 7 | tual
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | oga
# Processing Record 29 of Set 7 | gamboma
# Processing Record 30 of Set 7 | divnomorskoye
# Processing Record 31 of Set 7 | vagur
# Processing Record 32 of Set 7 | guerrero negro
# Processing Record 33 of Set 7 | ingham
# Processing Record 34 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 7 | tessalit
# Processing Record 36 of Set 7 | ordynskoye
# Processing Record 37 of Set 7 | do gonbadan
# Processing Record 38 of Set 7 | klaksvik
# Processing Record 39 of Set 7 | charters towers
# Processing Record 40 of Set 7 | meulaboh
# Processing Record 41 of Set 7 | codrington
# Processing Record 42 of Set 7 | manzanillo
# Processing Record 43 of Set 7 | beyneu
# Processing Record 44 of Set 7 | san patricio
# Processing Record 45 of Set 7 | bandarbeyla
# Processing Record 46 of Set 7 | naze
# Processing Record 47 of Set 7 | oktyabrskiy
# Processing Record 48 of Set 7 | ulladulla
# Processing Record 49 of Set 7 | san quintin
# Processing Record 50 of Set 7 | berlevag
# Processing Record 1 of Set 8 | ogaminana
# Processing Record 2 of Set 8 | lorengau
# Processing Record 3 of Set 8 | miri
# Processing Record 4 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 8 | aleksandrovskoye
# Processing Record 6 of Set 8 | bridlington
# Processing Record 7 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 8 of Set 8 | nadym
# Processing Record 9 of Set 8 | burnie
# Processing Record 10 of Set 8 | pilane
# Processing Record 11 of Set 8 | nanton
# Processing Record 12 of Set 8 | breves
# Processing Record 13 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 8 | pacific grove
# Processing Record 15 of Set 8 | russell
# Processing Record 16 of Set 8 | port augusta
# Processing Record 17 of Set 8 | tazovskiy
# Processing Record 18 of Set 8 | tura
# Processing Record 19 of Set 8 | pimentel
# Processing Record 20 of Set 8 | mitsamiouli
# Processing Record 21 of Set 8 | kimberley
# Processing Record 22 of Set 8 | magadan
# Processing Record 23 of Set 8 | cayenne
# Processing Record 24 of Set 8 | kuytun
# Processing Record 25 of Set 8 | constitucion
# Processing Record 26 of Set 8 | pinega
# Processing Record 27 of Set 8 | luorong
# Processing Record 28 of Set 8 | tongren
# Processing Record 29 of Set 8 | haines junction
# Processing Record 30 of Set 8 | chivay
# Processing Record 31 of Set 8 | nantucket
# Processing Record 32 of Set 8 | hualmay
# Processing Record 33 of Set 8 | sakaraha
# Processing Record 34 of Set 8 | warrington
# Processing Record 35 of Set 8 | makakilo city
# Processing Record 36 of Set 8 | peniche
# Processing Record 37 of Set 8 | shache
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | savda
# Processing Record 40 of Set 8 | ust-kulom
# Processing Record 41 of Set 8 | kieta
# Processing Record 42 of Set 8 | elat
# Processing Record 43 of Set 8 | barranca
# Processing Record 44 of Set 8 | husavik
# Processing Record 45 of Set 8 | young
# Processing Record 46 of Set 8 | yerbogachen
# Processing Record 47 of Set 8 | andarab
# City not found. Skipping...
# Processing Record 48 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 8 | tromso
# Processing Record 50 of Set 8 | sisimiut
# Processing Record 1 of Set 9 | namatanai
# Processing Record 2 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 9 | zarand
# Processing Record 4 of Set 9 | kaiyuan
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | spirit river
# Processing Record 7 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 9 | krasnoborsk
# Processing Record 9 of Set 9 | kapit
# Processing Record 10 of Set 9 | boffa
# Processing Record 11 of Set 9 | shelburne
# Processing Record 12 of Set 9 | oussouye
# Processing Record 13 of Set 9 | khandyga
# Processing Record 14 of Set 9 | zhenlai
# Processing Record 15 of Set 9 | pisco
# Processing Record 16 of Set 9 | general pico
# Processing Record 17 of Set 9 | salalah
# Processing Record 18 of Set 9 | ixtapa
# Processing Record 19 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 9 | saint anthony
# Processing Record 21 of Set 9 | kang
# Processing Record 22 of Set 9 | kashi
# Processing Record 23 of Set 9 | north bend
# Processing Record 24 of Set 9 | jaisalmer
# Processing Record 25 of Set 9 | smolenka
# Processing Record 26 of Set 9 | krutinka
# Processing Record 27 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 28 of Set 9 | fare
# Processing Record 29 of Set 9 | bail hongal
# Processing Record 30 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 9 | tianmen
# Processing Record 34 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 9 | aldan
# Processing Record 36 of Set 9 | nanortalik
# Processing Record 37 of Set 9 | san carlos de bariloche
# Processing Record 38 of Set 9 | nyurba
# Processing Record 39 of Set 9 | alyangula
# Processing Record 40 of Set 9 | mullovka
# Processing Record 41 of Set 9 | borogontsy
# Processing Record 42 of Set 9 | concepcion del oro
# Processing Record 43 of Set 9 | cherskiy
# Processing Record 44 of Set 9 | warrensburg
# Processing Record 45 of Set 9 | kondinskoye
# Processing Record 46 of Set 9 | chumikan
# Processing Record 47 of Set 9 | lifford
# Processing Record 48 of Set 9 | luderitz
# Processing Record 49 of Set 9 | mohpa
# Processing Record 50 of Set 9 | ban nahin
# Processing Record 1 of Set 10 | honiton
# Processing Record 2 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 10 | chibombo
# Processing Record 4 of Set 10 | middelburg
# Processing Record 5 of Set 10 | polunochnoye
# Processing Record 6 of Set 10 | el campo
# Processing Record 7 of Set 10 | williams lake
# Processing Record 8 of Set 10 | williamsport
# Processing Record 9 of Set 10 | maine-soroa
# Processing Record 10 of Set 10 | kasongo-lunda
# Processing Record 11 of Set 10 | betlitsa
# Processing Record 12 of Set 10 | saskylakh
# Processing Record 13 of Set 10 | talcahuano
# Processing Record 14 of Set 10 | winnemucca
# Processing Record 15 of Set 10 | camacha
# Processing Record 16 of Set 10 | veraval
# Processing Record 17 of Set 10 | marsh harbour
# Processing Record 18 of Set 10 | lindi
# Processing Record 19 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 10 | westport
# Processing Record 21 of Set 10 | stonewall
# Processing Record 22 of Set 10 | vila franca do campo
# Processing Record 23 of Set 10 | lom sak
# Processing Record 24 of Set 10 | bairiki
# Processing Record 25 of Set 10 | verin
# Processing Record 26 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 10 | sigli
# Processing Record 28 of Set 10 | fram
# Processing Record 29 of Set 10 | mazamari
# Processing Record 30 of Set 10 | buala
# Processing Record 31 of Set 10 | filingue
# Processing Record 32 of Set 10 | ketchikan
# Processing Record 33 of Set 10 | blairmore
# Processing Record 34 of Set 10 | pochutla
# Processing Record 35 of Set 10 | awjilah
# Processing Record 36 of Set 10 | avera
# Processing Record 37 of Set 10 | kirakira
# Processing Record 38 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 10 | santa maria
# Processing Record 40 of Set 10 | nola
# Processing Record 41 of Set 10 | zonguldak
# Processing Record 42 of Set 10 | gubin
# Processing Record 43 of Set 10 | kachug
# Processing Record 44 of Set 10 | kupang
# Processing Record 45 of Set 10 | kandrian
# Processing Record 46 of Set 10 | wanning
# Processing Record 47 of Set 10 | yenangyaung
# Processing Record 48 of Set 10 | korla
# Processing Record 49 of Set 10 | havre-saint-pierre
# Processing Record 50 of Set 10 | saldanha
# Processing Record 1 of Set 11 | mbandaka
# Processing Record 2 of Set 11 | vasai
# Processing Record 3 of Set 11 | sao gabriel da cachoeira
# Processing Record 4 of Set 11 | darab
# Processing Record 5 of Set 11 | havoysund
# Processing Record 6 of Set 11 | marsa matruh
# Processing Record 7 of Set 11 | shenjiamen
# Processing Record 8 of Set 11 | vuktyl
# Processing Record 9 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 11 | makubetsu
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | blythe
# Processing Record 13 of Set 11 | praia da vitoria
# Processing Record 14 of Set 11 | lompoc
# Processing Record 15 of Set 11 | flin flon
# Processing Record 16 of Set 11 | bucerias
# Processing Record 17 of Set 11 | homer
# Processing Record 18 of Set 11 | gander
# Processing Record 19 of Set 11 | zeya
# Processing Record 20 of Set 11 | gorom-gorom
# Processing Record 21 of Set 11 | ivankiv
# Processing Record 22 of Set 11 | balaipungut
# Processing Record 23 of Set 11 | sambava
# Processing Record 24 of Set 11 | verkhoyansk
# Processing Record 25 of Set 11 | cruzeiro do sul
# Processing Record 26 of Set 11 | fallon
# Processing Record 27 of Set 11 | amahai
# Processing Record 28 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 11 | huanuco
# Processing Record 31 of Set 11 | plouzane
# Processing Record 32 of Set 11 | bobrovytsya
# Processing Record 33 of Set 11 | harper
# Processing Record 34 of Set 11 | penzance
# Processing Record 35 of Set 11 | colorado springs
# Processing Record 36 of Set 11 | bayji
# Processing Record 37 of Set 11 | taraz
# Processing Record 38 of Set 11 | champerico
# Processing Record 39 of Set 11 | sioni
# Processing Record 40 of Set 11 | dovolnoye
# Processing Record 41 of Set 11 | maceio
# Processing Record 42 of Set 11 | sinnamary
# Processing Record 43 of Set 11 | honningsvag
# Processing Record 44 of Set 11 | baranchinskiy
# Processing Record 45 of Set 11 | qaqortoq
# Processing Record 46 of Set 11 | kailua
# Processing Record 47 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 11 | clawson
# Processing Record 49 of Set 11 | tiarei
# Processing Record 50 of Set 11 | tanete
# Processing Record 1 of Set 12 | pundaguitan
# Processing Record 2 of Set 12 | lerum
# Processing Record 3 of Set 12 | whitehorse
# Processing Record 4 of Set 12 | severnoye
# Processing Record 5 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 6 of Set 12 | zhizdra
# Processing Record 7 of Set 12 | seoul
# Processing Record 8 of Set 12 | barentu
# Processing Record 9 of Set 12 | katsuura
# Processing Record 10 of Set 12 | saint-joseph
# Processing Record 11 of Set 12 | dudinka
# Processing Record 12 of Set 12 | kazachinskoye
# Processing Record 13 of Set 12 | raudeberg
# Processing Record 14 of Set 12 | kingsville
# Processing Record 15 of Set 12 | burica
# City not found. Skipping...
# Processing Record 16 of Set 12 | kostomuksha
# Processing Record 17 of Set 12 | aran
# Processing Record 18 of Set 12 | jaguey grande
# Processing Record 19 of Set 12 | nuuk
# Processing Record 20 of Set 12 | kaeo
# Processing Record 21 of Set 12 | izumo
# Processing Record 22 of Set 12 | tekeli
# Processing Record 23 of Set 12 | hjelset
# Processing Record 24 of Set 12 | quincy
# Processing Record 25 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 12 | kushmurun
# Processing Record 27 of Set 12 | kununurra
# Processing Record 28 of Set 12 | rio tuba
# Processing Record 29 of Set 12 | gemena
# Processing Record 30 of Set 12 | rudnogorsk
# Processing Record 31 of Set 12 | santa marta
# Processing Record 32 of Set 12 | xining
# Processing Record 33 of Set 12 | bela
# Processing Record 34 of Set 12 | samfya
# Processing Record 35 of Set 12 | aykhal
# Processing Record 36 of Set 12 | yinchuan
# Processing Record 37 of Set 12 | talnakh
# Processing Record 38 of Set 12 | hobyo
# Processing Record 39 of Set 12 | solvychegodsk
# Processing Record 40 of Set 12 | guaraniacu
# Processing Record 41 of Set 12 | broken hill
# Processing Record 42 of Set 12 | lamu
# Processing Record 43 of Set 12 | ndele
# Processing Record 44 of Set 12 | isangel
# Processing Record 45 of Set 12 | shambu
# Processing Record 46 of Set 12 | catalina
# Processing Record 47 of Set 12 | fort nelson
# Processing Record 48 of Set 12 | konosha
# Processing Record 49 of Set 12 | igarka
# Processing Record 50 of Set 12 | rawson
# Processing Record 1 of Set 13 | kattivakkam
# Processing Record 2 of Set 13 | paita
# Processing Record 3 of Set 13 | cacule
# Processing Record 4 of Set 13 | reading
# Processing Record 5 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 6 of Set 13 | baghmara
# Processing Record 7 of Set 13 | benguela
# Processing Record 8 of Set 13 | moberly
# Processing Record 9 of Set 13 | victoria point
# Processing Record 10 of Set 13 | erzin
# Processing Record 11 of Set 13 | san luis rio colorado
# Processing Record 12 of Set 13 | sitka
# Processing Record 13 of Set 13 | braunau
# Processing Record 14 of Set 13 | santa clara
# Processing Record 15 of Set 13 | abha
# Processing Record 16 of Set 13 | kingaroy
# Processing Record 17 of Set 13 | gondanglegi
# Processing Record 18 of Set 13 | gornouralskiy
# City not found. Skipping...
# Processing Record 19 of Set 13 | skelleftea
# Processing Record 20 of Set 13 | kuah
# Processing Record 21 of Set 13 | kalabo
# Processing Record 22 of Set 13 | pitelino
# Processing Record 23 of Set 13 | chacabuco
# Processing Record 24 of Set 13 | nkwerre
# Processing Record 25 of Set 13 | puertollano
# Processing Record 26 of Set 13 | kokkola
# Processing Record 27 of Set 13 | inongo
# Processing Record 28 of Set 13 | rosarno
# Processing Record 29 of Set 13 | sultepec
# Processing Record 30 of Set 13 | mareeba
# Processing Record 31 of Set 13 | nalut
# Processing Record 32 of Set 13 | gerede
# Processing Record 33 of Set 13 | emerald
# Processing Record 34 of Set 13 | tonj
# Processing Record 35 of Set 13 | ferrol
# Processing Record 36 of Set 13 | auki
# Processing Record 37 of Set 13 | abu samrah
# Processing Record 38 of Set 13 | normandin
# Processing Record 39 of Set 13 | dzaoudzi
# Processing Record 40 of Set 13 | kholodnyy
# Processing Record 41 of Set 13 | caravelas
# Processing Record 42 of Set 13 | cockburn town
# Processing Record 43 of Set 13 | kavaratti
# Processing Record 44 of Set 13 | radom
# Processing Record 45 of Set 13 | tsumeb
# Processing Record 46 of Set 13 | tikrit
# Processing Record 47 of Set 13 | chililabombwe
# Processing Record 48 of Set 13 | kropotkin
# Processing Record 49 of Set 13 | edinburgh
# Processing Record 50 of Set 13 | gazimurskiy zavod
# Processing Record 1 of Set 14 | nizhniy tsasuchey
# Processing Record 2 of Set 14 | tahoua
# Processing Record 3 of Set 14 | rozivka
# Processing Record 4 of Set 14 | faya
# Processing Record 5 of Set 14 | okha
# Processing Record 6 of Set 14 | tumpat
# Processing Record 7 of Set 14 | mangrol
# Processing Record 8 of Set 14 | roswell
# Processing Record 9 of Set 14 | pavlovsk
# Processing Record 10 of Set 14 | turukhansk
# Processing Record 11 of Set 14 | finschhafen
# Processing Record 12 of Set 14 | rundu
# Processing Record 13 of Set 14 | anadyr
# Processing Record 14 of Set 14 | hovd
# Processing Record 15 of Set 14 | rosarito
# Processing Record 16 of Set 14 | sanmenxia
# Processing Record 17 of Set 14 | puksoozero
# Processing Record 18 of Set 14 | jalu
# Processing Record 19 of Set 14 | alberdi
# Processing Record 20 of Set 14 | antofagasta
# Processing Record 21 of Set 14 | batagay
# Processing Record 22 of Set 14 | wolmaranstad
# City not found. Skipping...
# Processing Record 23 of Set 14 | lakes entrance
# Processing Record 24 of Set 14 | davidson
# Processing Record 25 of Set 14 | canaries
# Processing Record 26 of Set 14 | birjand
# Processing Record 27 of Set 14 | lima
# Processing Record 28 of Set 14 | kindu
# Processing Record 29 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 30 of Set 14 | soyo
# Processing Record 31 of Set 14 | umm kaddadah
# Processing Record 32 of Set 14 | asosa
# Processing Record 33 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 14 | vila
# Processing Record 35 of Set 14 | mackay
# Processing Record 36 of Set 14 | corning
# Processing Record 37 of Set 14 | jiutai
# Processing Record 38 of Set 14 | parabel
# Processing Record 39 of Set 14 | krumovgrad
# Processing Record 40 of Set 14 | sumiswald
# Processing Record 41 of Set 14 | port hardy
# Processing Record 42 of Set 14 | la ronge
# Processing Record 43 of Set 14 | puerto del rosario
# Processing Record 44 of Set 14 | san jeronimo
# Processing Record 45 of Set 14 | northam
# Processing Record 46 of Set 14 | silae
# Processing Record 47 of Set 14 | kroderen
# City not found. Skipping...
# Processing Record 48 of Set 14 | melfi
# Processing Record 49 of Set 14 | baixa grande
# Processing Record 50 of Set 14 | turan
# Processing Record 1 of Set 15 | jay
# Processing Record 2 of Set 15 | pokhara
# Processing Record 3 of Set 15 | guasdualito
# Processing Record 4 of Set 15 | nizwa
# Processing Record 5 of Set 15 | tezu
# Processing Record 6 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 15 | surt
# Processing Record 8 of Set 15 | manacapuru
# Processing Record 9 of Set 15 | ostrovnoy
# Processing Record 10 of Set 15 | port moresby
# Processing Record 11 of Set 15 | itapetininga
# Processing Record 12 of Set 15 | valparaiso
# Processing Record 13 of Set 15 | mount pleasant
# Processing Record 14 of Set 15 | axim
# Processing Record 15 of Set 15 | bam
# Processing Record 16 of Set 15 | goundi
# Processing Record 17 of Set 15 | sungairaya
# Processing Record 18 of Set 15 | maldonado
# Processing Record 19 of Set 15 | mamou
# Processing Record 20 of Set 15 | urumqi
# Processing Record 21 of Set 15 | saint-georges
# Processing Record 22 of Set 15 | haapiti
# Processing Record 23 of Set 15 | palu
# Processing Record 24 of Set 15 | dutse
# Processing Record 25 of Set 15 | victor harbor
# Processing Record 26 of Set 15 | mitu
# Processing Record 27 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 15 | susanville
# Processing Record 29 of Set 15 | la seyne-sur-mer
# Processing Record 30 of Set 15 | necochea
# Processing Record 31 of Set 15 | kapoeta
# Processing Record 32 of Set 15 | fushan
# Processing Record 33 of Set 15 | glowno
# Processing Record 34 of Set 15 | manakara
# Processing Record 35 of Set 15 | vestmanna
# Processing Record 36 of Set 15 | marfino
# Processing Record 37 of Set 15 | ferkessedougou
# Processing Record 38 of Set 15 | fowa
# Processing Record 39 of Set 15 | basco
# Processing Record 40 of Set 15 | birao
# Processing Record 41 of Set 15 | gondar
# Processing Record 42 of Set 15 | abbeville
# Processing Record 43 of Set 15 | san rafael del sur
# Processing Record 44 of Set 15 | aurora
# Processing Record 45 of Set 15 | ginda
# Processing Record 46 of Set 15 | dhidhdhoo
# Processing Record 47 of Set 15 | asifabad
# Processing Record 48 of Set 15 | kaihua
# Processing Record 49 of Set 15 | aitape
# Processing Record 50 of Set 15 | kudymkar
# Processing Record 1 of Set 16 | weligama
# Processing Record 2 of Set 16 | eureka
# Processing Record 3 of Set 16 | chiali
# City not found. Skipping...
# Processing Record 4 of Set 16 | cap malheureux
# Processing Record 5 of Set 16 | pizarro
# Processing Record 6 of Set 16 | san pedro
# Processing Record 7 of Set 16 | novonukutskiy
# Processing Record 8 of Set 16 | rogun
# City not found. Skipping...
# Processing Record 9 of Set 16 | comodoro rivadavia
# Processing Record 10 of Set 16 | mangan
# Processing Record 11 of Set 16 | camana
# Processing Record 12 of Set 16 | zhanaozen
# Processing Record 13 of Set 16 | baykit
# Processing Record 14 of Set 16 | takoradi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kemijarvi  66.7131   27.4306     30.11        97         100
# 1        Ushuaia -54.8000  -68.3000     41.00        93          75
# 2         Cernay  47.8097    7.1770     43.00        65           0
# 3           Poum -20.2333  164.0167     79.00        77         100
# 4    New Norfolk -42.7826  147.0587     57.00        67         100
# ..           ...      ...       ...       ...       ...         ...
# 692       Mangan  27.5167   88.5333     72.61        30           0
# 693       Camana -16.6228  -72.7111     68.11        85          71
# 694    Zhanaozen  43.3000   52.8000     62.02        21         100
# 695       Baykit  61.6700   96.3700     31.91        78          97
# 696     Takoradi   4.8845   -1.7554     80.78        87          99
#
#      Wind Speed Country Current Description                 Date
# 0         10.63      FI                snow  2021-04-23 02:05:18
# 1         11.50      AR       broken clouds  2021-04-23 02:04:34
# 2          5.75      FR           clear sky  2021-04-23 02:05:18
# 3          5.91      NC     overcast clouds  2021-04-23 02:05:18
# 4          5.01      AU     overcast clouds  2021-04-23 02:05:19
# ..          ...     ...                 ...                  ...
# 692        1.03      IN           clear sky  2021-04-23 02:08:50
# 693        7.99      PE       broken clouds  2021-04-23 02:08:51
# 694       13.89      KZ     overcast clouds  2021-04-23 02:08:51
# 695        6.46      RU     overcast clouds  2021-04-23 02:08:51
# 696        7.43      GH     overcast clouds  2021-04-23 02:07:01
#
# [697 rows x 10 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
